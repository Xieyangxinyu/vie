# %%
import numpy as np
from Mondrian_matrix_utils import simulate, simulate_best
import pickle
import matplotlib.pyplot as plt
from scipy.stats import special_ortho_group

def simulate_y(x, rotation, seed = 0, noise_sig2 = 0.0001):
    res = np.matmul(x[:, 0:5], rotation)
    y = res[:, 0]**4 + res[:, 1]**4 + res[:, 2]**4 + res[:, 3]**4 + res[:, 4]**4
    r_noise = np.random.RandomState(seed)
    n = len(x)
    noise = r_noise.randn(n, 1) * np.sqrt(noise_sig2)
    y = y + noise[:, 0]
    return y

# %%
n = 20000
dim_in = 25
rotation = special_ortho_group.rvs(5)
#print(rotation)
x_train = np.random.rand(n,dim_in)*2 - 1
y_train = simulate_y(x_train, rotation)

x_test = np.random.rand(5000,dim_in)*2 - 1
y_test = simulate_y(x_test, rotation)

sample_range = [100, 1000, 2500, 5000, 7500, 10000, 15000, 20000]

M = 100                      # number of Mondrian trees to use
lifetime_max = 0.1          # terminal lifetime
weights_lifetime = 2*1e-6   # lifetime for which weights should be plotted
delta = 0.1              # ridge regression delta

pickle.dump(rotation, open("rotation.pk", "wb"))

# %%
stats = []

for n_sim in sample_range:
    print(f"number of training samples: {n_sim}")
    mse = {'n': n_sim, 'before': [], "after": []}
    for round in range(5):
        print(f"Simulation: {round}")
        mse_before, mse_after = simulate(x_train[:n_sim, ], y_train[:n_sim], x_test, y_test, M, lifetime_max, delta, weights_lifetime)
        mse['before'].append(mse_before)
        mse['after'].append(mse_after)
    stats.append(mse)

pickle.dump(stats, open("stat.pk", "wb"))
# Out:
# number of training samples: 100
# Simulation: 0
# Test mean squared error before transformation: 1.6104533891439516
# Test mean squared error after transformation: 1.5945673905753186
# Simulation: 1
# Test mean squared error before transformation: 1.6256097836683818
# Test mean squared error after transformation: 1.5886645428426533
# Simulation: 2
# Test mean squared error before transformation: 1.624678624992357
# Test mean squared error after transformation: 1.6233550352797135
# Simulation: 3
# Test mean squared error before transformation: 1.6136302334507542
# Test mean squared error after transformation: 1.6081589268552179
# Simulation: 4
# Test mean squared error before transformation: 1.6289463066925767
# Test mean squared error after transformation: 1.6498524776148973
# number of training samples: 1000
# Simulation: 0
# Test mean squared error before transformation: 1.6266439962349886
# Test mean squared error after transformation: 1.5408246691915124
# Simulation: 1
# Test mean squared error before transformation: 1.613870015583957
# Test mean squared error after transformation: 1.512510347907903
# Simulation: 2
# Test mean squared error before transformation: 1.6248413362458152
# Test mean squared error after transformation: 1.5639154296125086
# Simulation: 3
# Test mean squared error before transformation: 1.6218007113168784
# Test mean squared error after transformation: 1.5750102499421426
# Simulation: 4
# Test mean squared error before transformation: 1.6253041647697655
# Test mean squared error after transformation: 1.5628896628744597
# number of training samples: 2500
# Simulation: 0
# Test mean squared error before transformation: 1.60226622258405
# Test mean squared error after transformation: 1.4484599976772776
# Simulation: 1
# Test mean squared error before transformation: 1.6159882457565633
# Test mean squared error after transformation: 1.4755569607086472
# Simulation: 2
# Test mean squared error before transformation: 1.6160317305272973
# Test mean squared error after transformation: 1.4673243590770946
# Simulation: 3
# Test mean squared error before transformation: 1.6215521048854293
# Test mean squared error after transformation: 1.486683923316737
# Simulation: 4
# Test mean squared error before transformation: 1.6143978563770491
# Test mean squared error after transformation: 1.474259979767263
# number of training samples: 5000
# Simulation: 0
# Test mean squared error before transformation: 1.616971817390761
# Test mean squared error after transformation: 1.4827462228124877
# Simulation: 1
# Test mean squared error before transformation: 1.6157860268330169
# Test mean squared error after transformation: 1.445679796279574
# Simulation: 2
# Test mean squared error before transformation: 1.613967866173334
# Test mean squared error after transformation: 1.4671593640429736
# Simulation: 3
# Test mean squared error before transformation: 1.6230857104922358
# Test mean squared error after transformation: 1.4702787437770906
# Simulation: 4
# Test mean squared error before transformation: 1.6106558804212723
# Test mean squared error after transformation: 1.4554501952641612
# number of training samples: 7500
# Simulation: 0
# Test mean squared error before transformation: 1.6220548234761143
# Test mean squared error after transformation: 1.4893518428548949
# Simulation: 1
# Test mean squared error before transformation: 1.6216568753631506
# Test mean squared error after transformation: 1.4756084006863897
# Simulation: 2
# Test mean squared error before transformation: 1.6174771851177412
# Test mean squared error after transformation: 1.4536341972446645
# Simulation: 3
# Test mean squared error before transformation: 1.6252290294320064
# Test mean squared error after transformation: 1.4850035942727733
# Simulation: 4
# Test mean squared error before transformation: 1.622565180310652
# Test mean squared error after transformation: 1.5027515399966955
# number of training samples: 10000
# Simulation: 0
# Test mean squared error before transformation: 1.6069319564794313
# Test mean squared error after transformation: 1.4571297583171723
# Simulation: 1
# Test mean squared error before transformation: 1.6298803656719254
# Test mean squared error after transformation: 1.4826711435140019
# Simulation: 2
# Test mean squared error before transformation: 1.6145320832063856
# Test mean squared error after transformation: 1.4692650696599026
# Simulation: 3
# Test mean squared error before transformation: 1.6150544012183399
# Test mean squared error after transformation: 1.4606037448408165
# Simulation: 4
# Test mean squared error before transformation: 1.6172495001693432
# Test mean squared error after transformation: 1.463774757852485
# number of training samples: 15000
# Simulation: 0
# Test mean squared error before transformation: 1.6140480635531118
# Test mean squared error after transformation: 1.4680319121351448
# Simulation: 1
# Test mean squared error before transformation: 1.6077060256458857
# Test mean squared error after transformation: 1.4699075955286214
# Simulation: 2
# Test mean squared error before transformation: 1.6215016744695803
# Test mean squared error after transformation: 1.4852562020803965
# Simulation: 3
# Test mean squared error before transformation: 1.6231196927617313
# Test mean squared error after transformation: 1.4897534875400302
# Simulation: 4
# Test mean squared error before transformation: 1.6130711803796
# Test mean squared error after transformation: 1.4589045026100527
# number of training samples: 20000
# Simulation: 0
# Test mean squared error before transformation: 1.618275660774075
# Test mean squared error after transformation: 1.4573353117006445
# Simulation: 1
# Test mean squared error before transformation: 1.620617870848479
# Test mean squared error after transformation: 1.4511525817536604
# Simulation: 2
# Test mean squared error before transformation: 1.6319897721586825
# Test mean squared error after transformation: 1.4822376428804265
# Simulation: 3
# Test mean squared error before transformation: 1.6220823184581958
# Test mean squared error after transformation: 1.4713359099588956
# Simulation: 4
# Test mean squared error before transformation: 1.6227736107614186
# Test mean squared error after transformation: 1.4709037669604288

# %%
x = sample_range
before = []
before_min = []
before_max = []
after = []
after_min = []
after_max = []

for stat in stats:
    before.append(np.mean(stat['before']))
    before_min.append(np.min(stat['before']))
    before_max.append(np.max(stat['before']))
    after.append(np.mean(stat['after']))
    after_min.append(np.min(stat['after']))
    after_max.append(np.max(stat['after']))

fig, ax = plt.subplots()
ax.plot(x, before, color='b')
ax.plot(x, after, color='r')
ax.fill_between(x, (before_min), (before_max), color='b', alpha=.1)
ax.fill_between(x, (after_min), (after_max), color='r', alpha=.1)

plt.legend(["mse_before", "mse_after"], loc ="upper right")

# %%
stats_best = {}
best = {}

for multiplier in range(1,6):
    print(f"lifetime multiplier: {multiplier}")
    stats_best[multiplier] = []
    best[multiplier] = {"mean": [], "min": [], "max": []}
    for n_sim in sample_range:
        stats_temp = []
        print(f"number of training samples: {n_sim}")
        mse = {'n': n_sim, 'best': []}
        for round in range(5):
            print(f"Simulation: {round}")
            mse_best = simulate_best(x_train[:n_sim, ], y_train[:n_sim], x_test, y_test, M, lifetime_max * (multiplier), delta, weights_lifetime)
            mse['best'].append(mse_best)
            print(mse_best)
        stats_best[multiplier].append(mse)
        best[multiplier]["mean"].append(np.mean(mse['best']))
        best[multiplier]["min"].append(np.min(mse['best']))
        best[multiplier]["max"].append(np.max(mse['best']))

pickle.dump(stats_best, open("stats_best.pk", "wb"))
# Out:
# lifetime multiplier: 1
# number of training samples: 100
# Simulation: 0
# 1.5098182394207842
# Simulation: 1
# 1.532169375674308
# Simulation: 2
# 1.5264643354719842
# Simulation: 3
# 1.5288293550557046
# Simulation: 4
# 1.539235754678384
# number of training samples: 1000
# Simulation: 0
# 1.540429004744767
# Simulation: 1
# 1.5091740035863703
# Simulation: 2
# 1.5306534182808869
# Simulation: 3
# 1.5133991135966505
# Simulation: 4
# 1.5108601751647612
# number of training samples: 2500
# Simulation: 0
# 1.5094537612413355
# Simulation: 1
# 1.5260159090756105
# Simulation: 2
# 1.4960931263988846
# Simulation: 3
# 1.4887477884889457
# Simulation: 4
# 1.5187844912916901
# number of training samples: 5000
# Simulation: 0
# 1.5425755844932085
# Simulation: 1
# 1.5123143109433659
# Simulation: 2
# 1.5315470695800124
# Simulation: 3
# 1.5093727922325157
# Simulation: 4
# 1.514293010378739
# number of training samples: 7500
# Simulation: 0
# 1.531360673754084
# Simulation: 1
# 1.5204757068506163
# Simulation: 2
# 1.5320145142276302
# Simulation: 3
# 1.5213323301637796
# Simulation: 4
# 1.5308912163815602
# number of training samples: 10000
# Simulation: 0
# 1.5060014585701864
# Simulation: 1
# 1.5300820943998714
# Simulation: 2
# 1.533992729082923
# Simulation: 3
# 1.522576688062476
# Simulation: 4
# 1.5109342874825344
# number of training samples: 15000
# Simulation: 0
# 1.508610114401002
# Simulation: 1
# 1.5392758601661567
# Simulation: 2
# 1.5350096500328643
# Simulation: 3
# 1.5373207659688963
# Simulation: 4
# 1.5511091473664376
# number of training samples: 20000
# Simulation: 0
# 1.5235788481574337
# Simulation: 1
# 1.5328066267774396
# Simulation: 2
# 1.5553130083569133
# Simulation: 3
# 1.5319784150598912
# Simulation: 4
# 1.5219268143498823
# lifetime multiplier: 2
# number of training samples: 100
# Simulation: 0
# 1.4628181573635866
# Simulation: 1
# 1.4541531377491341
# Simulation: 2
# 1.467545842383214
# Simulation: 3
# 1.4649014469189385
# Simulation: 4
# 1.4561981600398477
# number of training samples: 1000
# Simulation: 0
# 1.4569281897054682
# Simulation: 1
# 1.4846019074547563
# Simulation: 2
# 1.4791929973286602
# Simulation: 3
# 1.446419597986246
# Simulation: 4
# 1.456283147533486
# number of training samples: 2500
# Simulation: 0
# 1.4374884428954717
# Simulation: 1
# 1.4764761616810476
# Simulation: 2
# 1.4332680449927586
# Simulation: 3
# 1.4346860983026435
# Simulation: 4
# 1.470500641850436
# number of training samples: 5000
# Simulation: 0
# 1.439306036836775
# Simulation: 1
# 1.4645490882875722
# Simulation: 2
# 1.4619063814982125
# Simulation: 3
# 1.4790389394834036
# Simulation: 4
# 1.4666358284440602
# number of training samples: 7500
# Simulation: 0
# 1.4662832026666146
# Simulation: 1
# 1.4499574937573227
# Simulation: 2
# 1.4699807155662366
# Simulation: 3
# 1.4695156033835333
# Simulation: 4
# 1.4653618804344581
# number of training samples: 10000
# Simulation: 0
# 1.4571216761484846
# Simulation: 1
# 1.4631186025077114
# Simulation: 2
# 1.4396912230011858
# Simulation: 3
# 1.4816449202981246
# Simulation: 4
# 1.4713657722907472
# number of training samples: 15000
# Simulation: 0
# 1.455119305571479
# Simulation: 1
# 1.4865151620495567
# Simulation: 2
# 1.4659422336141656
# Simulation: 3
# 1.484376745805666
# Simulation: 4
# 1.4736821715569923
# number of training samples: 20000
# Simulation: 0
# 1.451947725960408
# Simulation: 1
# 1.4480151551855387
# Simulation: 2
# 1.4713161283328984
# Simulation: 3
# 1.4866447175169508
# Simulation: 4
# 1.4497318872314835
# lifetime multiplier: 3
# number of training samples: 100
# Simulation: 0
# 1.4401047966717238
# Simulation: 1
# 1.4458898631704469
# Simulation: 2
# 1.419639141249487
# Simulation: 3
# 1.4590527102236763
# Simulation: 4
# 1.46898068044442
# number of training samples: 1000
# Simulation: 0
# 1.4201169548918544
# Simulation: 1
# 1.4640898383725982
# Simulation: 2
# 1.441092192648654
# Simulation: 3
# 1.4373854057916526
# Simulation: 4
# 1.4296814696215523
# number of training samples: 2500
# Simulation: 0
# 1.4064445471318543
# Simulation: 1
# 1.4323164892240272
# Simulation: 2
# 1.4285688635202063
# Simulation: 3
# 1.4060505997955544
# Simulation: 4
# 1.4290520547930865
# number of training samples: 5000
# Simulation: 0
# 1.4283933712709251
# Simulation: 1
# 1.4357356717504044
# Simulation: 2
# 1.4288005870155045
# Simulation: 3
# 1.4154292854045951
# Simulation: 4
# 1.4296937760391424
# number of training samples: 7500
# Simulation: 0
# 1.427153515090421
# Simulation: 1
# 1.4351839445084846
# Simulation: 2
# 1.4339347320378704
# Simulation: 3
# 1.4345050299626891
# Simulation: 4
# 1.4542944229180967
# number of training samples: 10000
# Simulation: 0
# 1.4251330735373213
# Simulation: 1
# 1.4221092794676709
# Simulation: 2
# 1.4384370663810866
# Simulation: 3
# 1.4422657552378226
# Simulation: 4
# 1.4229563159849465
# number of training samples: 15000
# Simulation: 0
# 1.4414700082317813
# Simulation: 1
# 1.444871465227026
# Simulation: 2
# 1.4311421465963188
# Simulation: 3
# 1.4268574162123844
# Simulation: 4
# 1.4398619519431766
# number of training samples: 20000
# Simulation: 0
# 1.448744984427999
# Simulation: 1
# 1.441955088642432
# Simulation: 2
# 1.4343090129165408
# Simulation: 3
# 1.4302708380953493
# Simulation: 4
# 1.4317395546003178
# lifetime multiplier: 4
# number of training samples: 100
# Simulation: 0
# 1.4622456258809082
# Simulation: 1
# 1.4364270757428517
# Simulation: 2
# 1.451861447264786
# Simulation: 3
# 1.4272902645642038
# Simulation: 4
# 1.4127055949679015
# number of training samples: 1000
# Simulation: 0
# 1.4330541738901401
# Simulation: 1
# 1.4588456859933239
# Simulation: 2
# 1.4480919054256989
# Simulation: 3
# 1.4577741758511595
# Simulation: 4
# 1.454629132018958
# number of training samples: 2500
# Simulation: 0
# 1.438910232993526
# Simulation: 1
# 1.4449588244584133
# Simulation: 2
# 1.4030912264045021
# Simulation: 3
# 1.4319075683798248
# Simulation: 4
# 1.4169619597435525
# number of training samples: 5000
# Simulation: 0
# 1.4280177301547357
# Simulation: 1
# 1.4160366492469245
# Simulation: 2
# 1.4457651161657001
# Simulation: 3
# 1.4355131121541345
# Simulation: 4
# 1.4103219462451733
# number of training samples: 7500
# Simulation: 0
# 1.4340656181360263
# Simulation: 1
# 1.428305291954335
# Simulation: 2
# 1.4550535628079564
# Simulation: 3
# 1.412032165684984
# Simulation: 4
# 1.4184622134774085
# number of training samples: 10000
# Simulation: 0
# 1.4299701356712504
# Simulation: 1
# 1.4378000463865888
# Simulation: 2
# 1.4435444147526937
# Simulation: 3
# 1.4421641783334396
# Simulation: 4
# 1.419671373458287
# number of training samples: 15000
# Simulation: 0
# 1.4422039529918467
# Simulation: 1
# 1.4327651112649586
# Simulation: 2
# 1.4272431561893733
# Simulation: 3
# 1.4286601351889192
# Simulation: 4
# 1.4260301550095225
# number of training samples: 20000
# Simulation: 0
# 1.4178224837753106
# Simulation: 1
# 1.4469418566113004
# Simulation: 2
# 1.4595575862189771
# Simulation: 3
# 1.4377356741737821
# Simulation: 4
# 1.442503499055492
# lifetime multiplier: 5
# number of training samples: 100
# Simulation: 0
# 1.4300623905572825
# Simulation: 1
# 1.4329033854089503
# Simulation: 2
# 1.4295413522669005
# Simulation: 3
# 1.4504629816476122
# Simulation: 4
# 1.4484563028349193
# number of training samples: 1000
# Simulation: 0
# 1.4628833480294354
# Simulation: 1
# 1.4540760704199582
# Simulation: 2
# 1.4464160770675263
# Simulation: 3
# 1.4452547343537452
# Simulation: 4
# 1.4518185742168777
# number of training samples: 2500
# Simulation: 0
# 1.4213150454761947
# Simulation: 1
# 1.4240237183983655
# Simulation: 2
# 1.4282111419119914
# Simulation: 3
# 1.4124662404977315
# Simulation: 4
# 1.4224705895809475
# number of training samples: 5000
# Simulation: 0
# 1.4407821720224088
# Simulation: 1
# 1.4374124875212253
# Simulation: 2
# 1.4300732755676921
# Simulation: 3
# 1.4335027064937007
# Simulation: 4
# 1.4301941579729158
# number of training samples: 7500
# Simulation: 0
# 1.4453454448014624
# Simulation: 1
# 1.440581438733643
# Simulation: 2
# 1.4397361251333434
# Simulation: 3
# 1.4370745064437929
# Simulation: 4
# 1.4634557182404084
# number of training samples: 10000
# Simulation: 0
# 1.460239316862819
# Simulation: 1
# 1.4353864075719076
# Simulation: 2
# 1.4472820833794637
# Simulation: 3
# 1.440605439196652
# Simulation: 4
# 1.4427511163936781
# number of training samples: 15000
# Simulation: 0
# 1.4372027151519946
# Simulation: 1
# 1.4219172834442881
# Simulation: 2
# 1.443337462361968
# Simulation: 3
# 1.4474882799249387
# Simulation: 4
# 1.4348958473280617
# number of training samples: 20000
# Simulation: 0
# 1.4494179303990922
# Simulation: 1
# 1.4567685442864233
# Simulation: 2
# 1.4427577735196446
# Simulation: 3
# 1.4457324639400368
# Simulation: 4
# 1.4205118278875475

# %%
colors = plt.cm.rainbow(np.linspace(0, 1, 7))

fig, ax = plt.subplots(figsize=(15,8))

ax.plot(x, before, color=colors[0])
ax.plot(x, after, color=colors[6])
for multiplier in range(1,6):
    ax.plot(x, best[multiplier]["mean"], color=colors[multiplier])
plt.legend(["mse_before", "mse_after", "mse_best_1", "mse_best_2", "mse_best_3", "mse_best_4", "mse_best_5"], loc ="upper right")
ax.fill_between(x, (before_min), (before_max), color=colors[0], alpha=.1)
ax.fill_between(x, (after_min), (after_max), color=colors[6], alpha=.1)
for multiplier in range(1,6):
    ax.fill_between(x, (best[multiplier]["min"]), (best[multiplier]["max"]), color=colors[multiplier], alpha=.1)
